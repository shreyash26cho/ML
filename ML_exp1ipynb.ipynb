# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyash26cho/ML/blob/main/ML_exp1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

df = pd.read_csv('/content/housing1.csv.zip')
x=df['total_bedrooms']
y=df['median_house_value']

x1=x.values.reshape(-1,1)
y1=y.values.reshape(-1,1)

x=x1[0:15]
y=y1[0:15]

test_x=x1[15:20]
test_y=y1[15:20]

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.metrics import mean_squared_error
#
# model = SVR()
# model.fit(x,y.ravel())
#
# y_pred = model.predict(test_x)
# mse = mean_squared_error(test_y,y_pred)
#
# print("Mean Squared Error:",mse)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='red')
plt.scatter(test_x,y_pred,color='blue')
plt.plot(x,model.predict(x),color='green')
plt.title('Linear Regression')
plt.xlabel('total_bedrooms')
plt.ylabel('median_house_value')
plt.show()

# %% [markdown]
# ## Data exploration and preprocessing
#
# ### Subtask:
# Handle categorical features and scale numerical features.

# %% [markdown]
# **Reasoning**:
# I will now one-hot encode the `ocean_proximity` column and then use `StandardScaler` to scale the numerical features in the dataframe as requested by the instructions.

# %%
import matplotlib.pyplot as plt

# Plot the regression line
plt.scatter(x, y, color='red', label='Actual')
plt.scatter(test_x, y_pred, color='blue', label='Predicted')
plt.title('KNeighborsRegressor')
plt.xlabel('total_bedrooms')
plt.ylabel('median_house_value')
plt.legend()
plt.show()

# Plot the residuals
residuals = test_y.flatten() - y_pred.flatten()
plt.scatter(y_pred.flatten(), residuals)
plt.title('Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.show()
